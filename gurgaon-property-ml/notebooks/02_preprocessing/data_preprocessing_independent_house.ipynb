# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/independent-house - independent-house.csv')
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.shape
# Out:
# (1095, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            619
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     504
# address             64
# noOfFloor          127
# facing             420
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     350
# features           420
# rating             188
# property_id         59
# dtype: int64

# %%
df.drop(columns=['link','property_id'],inplace=True)

# %%
df.rename(columns={'rate':'price_per_sqft','noOfFloor':'floorNum'},inplace=True)
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['society'].value_counts()
# Out:
# society
# Emaar MGF Marbella                     26
# International City by SOBHA Phase 2    26
# Vipul Tatvam Villa                     25
# International City by Sobha Phase 1    23
# Unitech Uniworld Resorts               14
#                                        ..
# Ansal Sushant Lok 2                     1
# Sector 57 Huda                          1
# Godrej Meridien                         1
# Huda                                    1
# Huda Floor                              1
# Name: count, Length: 188, dtype: int64

# %%
df['society'].isnull().sum()
# Out:
# np.int64(619)

# %%
df['society'].fillna('independent',inplace=True)
# Out:
# /tmp/ipython-input-3658123046.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['society'].fillna('independent',inplace=True)

# %%
df['society'] = (
    df['society']
    .astype(str)
    .str.replace(r'\d+(\.\d+)?\s?★', '', regex=True)
    .str.strip()
    .str.lower()
)
df['society'].value_counts()
# Out:
# society
# independent                            619
# emaar mgf marbella                      26
# international city by sobha phase 2     26
# vipul tatvam villa                      25
# international city by sobha phase 1     23
#                                       ...
# ansal sushant lok 2                      1
# sector 57 huda                           1
# godrej meridien                          1
# huda                                     1
# huda floor                               1
# Name: count, Length: 186, dtype: int64

# %%
df[df['price'] == 'Price on Request'].shape[0]
# Out:
# 10

# %%
df=df[df['price'] != 'Price on Request']

# %%
df['price'].value_counts()
# Out:
# price
# 3.5 Crore     19
# 5.5 Crore     17
# 6.5 Crore     16
# 6 Crore       14
# 5 Crore       13
#               ..
# 3.8 Crore      1
# 7.45 Crore     1
# 7.42 Crore     1
# 6.09 Crore     1
# 2.98 Crore     1
# Name: count, Length: 301, dtype: int64

# %%
df=df[df['price'].str.split(" ").str.len()!=1]

# %%
## same scale
def price_scaling(x):
  if(type(x)==float):
    return x
  else:
    if(x[1]=='Lac'):
      return round(float(x[0])/100,2)
    else:
      return round(float(x[0]),2)

df['price']=df['price'].str.split(" ").apply(price_scaling)
df.head(5)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 22,222/sq.ft.    14
# ₹ 11,111/sq.ft.    12
# ₹ 33,333/sq.ft.    11
# ₹ 10,000/sq.ft.    10
# ₹ 37,037/sq.ft.     7
#                    ..
# ₹ 20,349/sq.ft.     1
# ₹ 20,566/sq.ft.     1
# ₹ 33,665/sq.ft.     1
# ₹ 6,230/sq.ft.      1
# ₹ 47,803/sq.ft.     1
# Name: count, Length: 776, dtype: int64

# %%
df
# Out:
#                                           property_name  \
# 0        5 Bedroom House for sale in Sector 70A Gurgaon
# 1      5 Bedroom House for sale in Sector 21A Faridabad
# 2      10 Bedroom House for sale in Sushant Lok Phase 1
# 3        21 Bedroom House for sale in Sector 54 Gurgaon
# 4      12 Bedroom House for sale in Sushant Lok Phase 1
# ...                                                 ...
# 1077                 3 Bedroom House for sale in Bissar
# 1078                 3 Bedroom House for sale in Bissar
# 1079            8 Bedroom House for sale in DLF Phase 2
# 1080  8 Bedroom House for sale in C Block Sushant Lo...
# 1081      2 Bedroom House for sale in Sector 92 Gurgaon
#
#                                        society  price    price_per_sqft  \
# 0                             bptp visionnaire   5.25   ₹ 20,115/sq.ft.
# 1                                  independent   5.70  ₹ 105,751/sq.ft.
# 2                                  independent   2.10   ₹ 38,251/sq.ft.
# ...

# %%
df['price_per_sqft']=df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype(float)
df.head(5)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
df['bedRoom'].isnull().sum()
# Out:
# np.int64(108)

# %%
# df['bedRoom'].fillna(int(df['bedRoom'].mean()),inplace=True)
df = df[~df['bedRoom'].isnull()]

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      31
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 11 Bedrooms      2
# 19 Bedrooms      2
# 18 Bedrooms      2
# 21 Bedrooms      1
# 20 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
df=df[~df['bedRoom'].isnull()]  # remove nan value
df['bedRoom']=df['bedRoom'].str.split(' ').str.get(0).astype(int)
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom      bathroom       balcony                      additionalRoom  \
# ...

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      28
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 13 Bathrooms      4
# 18 Bathrooms      4
# 11 Bathrooms      4
# 17 Bathrooms      3
# 20 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 34 Bathrooms      1
# 36 Bathrooms      1
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype(int)
df['bathroom']
# Out:
# 0        4
# 1        4
# 2       10
# 3       21
# 4       12
#         ..
# 1073     4
# 1074     2
# 1075     3
# 1076     3
# 1077     3
# Name: bathroom, Length: 964, dtype: int64

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony']=df['balcony'].str.split(' ').str.get(0).replace('No','0')
df['balcony'].value_counts()
# Out:
# balcony
# 3+    365
# 2     220
# 3     159
# 0     115
# 1     105
# Name: count, dtype: int64

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Others                                11
# Pooja Room,Store Room                            11
# Servant Room,Others                               8
# Pooja Room,Store Room,Study Room,Servant Room     8
# Servant Room,Pooja Room                           8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(386)

# %%
df['additionalRoom']=df['additionalRoom'].fillna("not available")
df['additionalRoom'] = df['additionalRoom'].str.lower().str.strip()
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# not available                                    386
# servant room                                      81
# pooja room,study room,servant room,store room     60
# others                                            58
# pooja room                                        38
# pooja room,study room,servant room                33
# pooja room,study room,servant room,others         32
# store room                                        31
# pooja room,servant room                           24
# study room                                        19
# study room,servant room                           19
# servant room,store room                           15
# pooja room,study room                             11
# pooja room,others                                 11
# pooja room,store room                             11
# servant room,others                                8
# pooja room,store room,study room,servant room      8
# ...

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 3 Floors     304
# 2 Floors     288
# 1 Floors     181
# 4 Floors     136
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 10 Floors      2
# 11 Floors      2
# 12 Floors      2
# 21 Floors      1
# 13 Floors      1
# 27 Floors      1
# 02 Floors      1
# 20 Floors      1
# 41 Floors      1
# 51 Floors      1
# 16 Floors      1
# 33 Floors      1
# Name: count, dtype: int64

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(19)

# %%
df=df[~df['floorNum'].isnull()] ## reomove nan value
df['floorNum']=df['floorNum'].str.lower().str.split(" ").str.get(0).str.replace('ground','0').str.replace('lower','0').str.replace('basement','-1').str.extract(r'(\d+)')
df['floorNum'].value_counts()
# Out:
# floorNum
# 3     304
# 2     288
# 1     181
# 4     136
# 5       9
# 0       6
# 14      3
# 6       3
# 10      2
# 11      2
# 12      2
# 21      1
# 13      1
# 27      1
# 02      1
# 20      1
# 41      1
# 51      1
# 16      1
# 33      1
# Name: count, dtype: int64

# %%
df['facing'].value_counts()
# Out:
# facing
# East          176
# North-East    157
# North         109
# West           73
# North-West     44
# South-East     39
# South          34
# South-West     22
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(291)

# %%
df['facing'].fillna('NA',inplace=True)
df['facing'].value_counts()
# Out:
# /tmp/ipython-input-1645566960.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)
# facing
# NA            291
# East          176
# North-East    157
# North         109
# West           73
# North-West     44
# South-East     39
# South          34
# South-West     22
# Name: count, dtype: int64

# %%
## new feature
df['area']=round((df['price']*10000000)/df['price_per_sqft'])
df['property_type']='independent-house'
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft    area                 areaWithType  bedRoom  bathroom  \
# 0         20115.0  2610.0  Plot area 290(242.48 sq.m.)        5         4
# 1        105751.0   539.0   Plot area 539(50.07 sq.m.)        5         4
# 2         38251.0   549.0       Plot area 61(51 sq.m.)       10        10
# 3         43066.0  1161.0  Plot area 129(107.86 sq.m.)       21        21
# 4         53763.0   558.0    Plot area 62(51.84 sq.m.)       12        12
#
#   balcony                      additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, 0 to 1077
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    945 non-null    object
#  1   society          945 non-null    object
#  2   price            926 non-null    float64
#  3   price_per_sqft   926 non-null    float64
#  4   area             926 non-null    float64
#  5   areaWithType     945 non-null    object
#  6   bedRoom          945 non-null    int64
#  7   bathroom         945 non-null    int64
#  8   balcony          945 non-null    object
#  9   additionalRoom   945 non-null    object
#  10  address          940 non-null    object
#  11  floorNum         945 non-null    object
#  12  facing           945 non-null    object
#  13  agePossession    945 non-null    object
#  14  nearbyLocations  830 non-null    object
#  15  description      945 non-null    object
#  16  furnishDetails   713 non-null    object
# ...

# %%
df.to_csv('independent-house_cleaned.csv',index=False)

# %%
df.sample(6)
# Out:
#                                       property_name  \
# 888         4 Bedroom House for sale in DLF Phase 1
# 215         7 Bedroom House for sale in DLF Phase 3
# 483        5 Bedroom House for sale in Laxman Vihar
# 443          5 Bedroom House for sale in Bhim Nagar
# 771  4 Bedroom House for sale in Sector 109 Gurgaon
# 242   5 Bedroom House for sale in Sector 72 Gurgaon
#
#                                  society  price  price_per_sqft    area  \
# 888                          independent  15.00         33333.0  4500.0
# 215                          independent   2.75          7666.0  3587.0
# 483                       not applicable    NaN             NaN     NaN
# 443                          independent   0.50         13889.0   360.0
# 771  international city by sobha phase 2   6.25         11574.0  5400.0
# 242                          spaze privy   3.10          8486.0  3653.0
#
#                            areaWithType  bedRoom  bathroom balcony  \
# ...
