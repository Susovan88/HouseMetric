# %%
import pandas as pd
import numpy as np

# %%
flats=pd.read_csv("/content/flats_cleaned.csv")
houses=pd.read_csv('/content/independent-house_cleaned.csv')

# %%
print(flats.shape,houses.shape)
# Out:
# (2995, 20) (945, 20)

# %%
df=pd.concat([flats,houses],ignore_index=True) # merge both data
df=df.sample(df.shape[0],ignore_index=True) ## apply sampling
df.head(6)
# Out:
#                                 property_name                society  price  \
# 0             3 BHK Flat in Sector 67 Gurgaon    ireo victory valley   2.99
# 1                  2 BHK Flat in Laxman Vihar         not applicable   0.42
# 2  5 Bedroom House for sale in Greenwood City            independent  17.00
# 3                         2 BHK Flat in Sohna  signature global park   0.68
# 4             4 BHK Flat in Sector 90 Gurgaon   dlf new town heights   1.42
# 5             3 BHK Flat in Sector 84 Gurgaon  alpha corp gurgaonone   1.50
#
#    price_per_sqft                                       areaWithType  bedRoom  \
# 0         11832.0  Super Built up area 2527(234.77 sq.m.)Built Up...        3
# 1          5600.0                     Carpet area: 750 (69.68 sq.m.)        2
# 2         37777.0                       Plot area 4500(418.06 sq.m.)        5
# 3          8252.0                     Carpet area: 824 (76.55 sq.m.)        2
# 4          4864.0             Super Built up area 2364(219.62 sq.m.)        4
# 5          7641.0  Super Built up area 1963(182.37 sq.m.)Carpet a...        3
#
#    bathroom balcony                                 additionalRoom  \
# 0         3       3                                   servant room
# 1         2       1                                  not available
# 2         8      3+  pooja room,study room,servant room,store room
# 3         2       2                                  not available
# 4         4      3+                        servant room,store room
# 5         3       3                                   servant room
#
#                                              address  floorNum      facing  \
# 0           702, Sector 67 Gurgaon, Gurgaon, Haryana         4        East
# 1  621/622, Gali No-4, Laxman Vihar, Gurgaon, Har...         3         NaN
# 2             0000, Greenwood City, Gurgaon, Haryana         3  North-East
# 3                            Sohna, Gurgaon, Haryana         3         NaN
# 4  Middle Floor, Sector 90 Gurgaon, Gurgaon, Haryana         8        East
# 5                Sector 84 Gurgaon, Gurgaon, Haryana        20  North-West
#
#       agePossession                                    nearbyLocations  \
# 0   1 to 5 Year Old  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1   1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2   1 to 5 Year Old  ['Huda city centre metro station', 'Axis bank ...
# 3   Within 6 months  ['Sector 55-56 metro', 'Global city centre', '...
# 4  5 to 10 Year Old  ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
# 5   1 to 5 Year Old  ['Delhi Public School', 'Raheja Market', 'Sapp...
#
#                                          description  \
# 0  Note- We deal exclusively in the society ireo ...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Ultra luxury kothi for sale in greenwood city ...
# 3  Signature global park is one of gurgaon's most...
# 4  This beautiful 4 bhk apartment/flat in sector-...
# 5  Alpha corp gurgaonone 84 is one of the most po...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 St...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['1 Water Purifier', '11 Fan', '1 Fridge', '1 ...
# 3  ['2 Wardrobe', '3 Fan', '3 Light', '1 Modular ...
# 4                                                NaN
# 5  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '3 Ge...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Intercom Facility',...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Shopping...
# 5  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                               rating    area  \
# 0  ['Green Area5 out of 5', 'Construction4 out of...  2527.0
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   750.0
# 2  ['Environment4.5 out of 5', 'Lifestyle4 out of...  4500.0
# 3  ['Green Area5 out of 5', 'Construction5 out of...   824.0
# 4  ['Green Area5 out of 5', 'Construction4 out of...  2919.0
# 5  ['Green Area5 out of 5', 'Construction5 out of...  1963.0
#
#        property_type
# 0               flat
# 1               flat
# 2  independent-house
# 3               flat
# 4               flat
# 5               flat

# %%
df.shape
# Out:
# (3940, 20)

# %%
df.to_csv('gurgaon_properties.csv',index=False)

# %%
df.describe()
# Out:
#              price  price_per_sqft      bedRoom     bathroom     floorNum  \
# count  3920.000000     3920.000000  3940.000000  3940.000000  3940.000000
# mean      2.463536    13808.636480     3.358122     3.403299     6.667766
# std       2.913842    22782.496918     2.002137     2.039603     6.005669
# min       0.070000        2.000000     1.000000     1.000000     0.000000
# 25%       0.900000     6788.500000     2.000000     2.000000     2.000000
# 50%       1.500000     8988.000000     3.000000     3.000000     4.000000
# 75%       2.650000    13713.000000     4.000000     4.000000    10.000000
# max      31.500000   600000.000000    36.000000    36.000000    51.000000
#
#                area
# count  3.920000e+03
# mean   4.658949e+03
# std    1.179001e+05
# min    4.500000e+01
# 25%    1.187000e+03
# 50%    1.700000e+03
# 75%    2.289250e+03
# max    7.250000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3940 entries, 0 to 3939
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3940 non-null   object
#  1   society          3940 non-null   object
#  2   price            3920 non-null   float64
#  3   price_per_sqft   3920 non-null   float64
#  4   areaWithType     3940 non-null   object
#  5   bedRoom          3940 non-null   int64
#  6   bathroom         3940 non-null   int64
#  7   balcony          3940 non-null   object
#  8   additionalRoom   3940 non-null   object
#  9   address          3929 non-null   object
#  10  floorNum         3940 non-null   int64
#  11  facing           2777 non-null   object
#  12  agePossession    3939 non-null   object
#  13  nearbyLocations  3736 non-null   object
#  14  description      3940 non-null   object
#  15  furnishDetails   2911 non-null   object
#  16  features         3241 non-null   object
#  17  rating           3495 non-null   object
#  18  area             3920 non-null   float64
#  19  property_type    3940 non-null   object
# dtypes: float64(3), int64(3), object(14)
# memory usage: 615.8+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# society               0
# price                20
# price_per_sqft       20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum              0
# facing             1163
# agePossession         1
# nearbyLocations     204
# description           0
# furnishDetails     1029
# features            699
# rating              445
# area                 20
# property_type         0
# dtype: int64

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())
df['sector'] = df['sector'].str.lower()
df.head()
# Out:
#                                 property_name                society  price  \
# 0             3 BHK Flat in Sector 67 Gurgaon    ireo victory valley   2.99
# 1                  2 BHK Flat in Laxman Vihar         not applicable   0.42
# 2  5 Bedroom House for sale in Greenwood City            independent  17.00
# 3                         2 BHK Flat in Sohna  signature global park   0.68
# 4             4 BHK Flat in Sector 90 Gurgaon   dlf new town heights   1.42
#
#            sector  price_per_sqft  \
# 0       sector 67         11832.0
# 1    laxman vihar          5600.0
# 2  greenwood city         37777.0
# 3           sohna          8252.0
# 4       sector 90          4864.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2527(234.77 sq.m.)Built Up...        3         3
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                       Plot area 4500(418.06 sq.m.)        5         8
# 3                     Carpet area: 824 (76.55 sq.m.)        2         2
# 4             Super Built up area 2364(219.62 sq.m.)        4         4
#
#   balcony                                 additionalRoom  ... floorNum  \
# 0       3                                   servant room  ...        4
# 1       1                                  not available  ...        3
# 2      3+  pooja room,study room,servant room,store room  ...        3
# 3       2                                  not available  ...        3
# 4      3+                        servant room,store room  ...        8
#
#        facing     agePossession  \
# 0        East   1 to 5 Year Old
# 1         NaN   1 to 5 Year Old
# 2  North-East   1 to 5 Year Old
# 3         NaN   Within 6 months
# 4        East  5 to 10 Year Old
#
#                                      nearbyLocations  \
# 0  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2  ['Huda city centre metro station', 'Axis bank ...
# 3  ['Sector 55-56 metro', 'Global city centre', '...
# 4  ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
#
#                                          description  \
# 0  Note- We deal exclusively in the society ireo ...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Ultra luxury kothi for sale in greenwood city ...
# 3  Signature global park is one of gurgaon's most...
# 4  This beautiful 4 bhk apartment/flat in sector-...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 St...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['1 Water Purifier', '11 Fan', '1 Fridge', '1 ...
# 3  ['2 Wardrobe', '3 Fan', '3 Light', '1 Modular ...
# 4                                                NaN
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Intercom Facility',...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Shopping...
#
#                                               rating    area  \
# 0  ['Green Area5 out of 5', 'Construction4 out of...  2527.0
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   750.0
# 2  ['Environment4.5 out of 5', 'Lifestyle4 out of...  4500.0
# 3  ['Green Area5 out of 5', 'Construction5 out of...   824.0
# 4  ['Green Area5 out of 5', 'Construction4 out of...  2919.0
#
#        property_type
# 0               flat
# 1               flat
# 2  independent-house
# 3               flat
# 4               flat
#
# [5 rows x 21 columns]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
#                                                             ...
# devi lal colony gali no 12 gurgaon nr omkar public school      1
# mahalaxmi garden, rajendra place                               1
# sector 37b                                                     1
# ram nagar                                                      1
# old delhi road, opp sector-14                                  1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')


df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road           163
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# maruti kunj            3
# patel nagar            3
# sector 73              3
# b block sector 43      3
# sector 110 a           3
# Name: count, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name                       society  price sector  \
# 731   2 BHK Flat in New Gurgaon  takshila heights sector 37 c   0.67    new
# 2709  4 BHK Flat in New Gurgaon                    sare homes   0.85    new
# 2742  4 BHK Flat in New Gurgaon                        dlf 76   4.00    new
# 3253  2 BHK Flat in New Gurgaon                   green court   0.38    new
#
#       price_per_sqft                            areaWithType  bedRoom  \
# 731           5583.0  Super Built up area 1200(111.48 sq.m.)        2
# 2709          4786.0     Super Built up area 1776(165 sq.m.)        4
# 2742         11428.0        Carpet area: 3500 (325.16 sq.m.)        4
# 3253          5507.0           Carpet area: 690 (64.1 sq.m.)        2
#
#       bathroom balcony           additionalRoom  ... floorNum  facing  \
# 731          2       2            not available  ...        3     NaN
# 2709         4       3            not available  ...        3     NaN
# 2742         4       2  study room,servant room  ...        4     NaN
# 3253         2       1            not available  ...        7     NaN
#
#            agePossession                                    nearbyLocations  \
# 731      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2709    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 2742            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3253  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
#
#                                             description  \
# 731   Check out this 2 bhk apartment for sale in tak...
# 2709  Located in the popular residential address of ...
# 2742  This lovely 4 bhk apartment/flat in new gurgao...
# 3253  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 731                                                  []
# 2709                                                 []
# 2742  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 3253                                                 []
#
#                                                features rating    area  \
# 731   ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN  1200.0
# 2709                                                NaN    NaN  1776.0
# 2742  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN  3500.0
# 3253  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN   690.0
#
#       property_type
# 731            flat
# 2709           flat
# 2742           flat
# 3253           flat
#
# [4 rows x 21 columns]

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name              society  price  \
# 1110                2 BHK Flat in New Palam Vihar              my home   0.28
# 1139                2 BHK Flat in New Palam Vihar  ompee k s residency   1.60
# 2563  2 Bedroom House for sale in New Palam Vihar              my home   0.34
# 3236                2 BHK Flat in New Palam Vihar              my home   0.22
# 3452  3 Bedroom House for sale in New Palam Vihar          independent   1.00
#
#             sector  price_per_sqft  \
# 1110  new sector 2          3166.0
# 1139  new sector 2         26936.0
# 2563  new sector 2         12592.0
# 3236  new sector 2          4400.0
# 3452  new sector 2          8796.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1110                     Carpet area: 900 (83.61 sq.m.)        2         1
# 1139                      Carpet area: 66 (55.18 sq.m.)        2         2
# 2563                         Plot area 270(25.08 sq.m.)        2         2
# 3236                     Carpet area: 500 (46.45 sq.m.)        2         2
# 3452  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
#
#      balcony additionalRoom  ... floorNum  facing     agePossession  \
# 1110       1         others  ...        2     NaN   1 to 5 Year Old
# 1139       2  not available  ...        1     NaN   1 to 5 Year Old
# 2563       2  not available  ...        3    West  5 to 10 Year Old
# 3236       1  not available  ...        1     NaN   0 to 1 Year Old
# 3452       2     pooja room  ...        1   North      10+ Year Old
#
#                                         nearbyLocations  \
# 1110  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1139  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2563  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3236  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3452  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 1110  2 bhk room with wooden coverd ,1 drawing room,...
# 1139  We are the proud owners of this 2 bhk apartmen...
# 2563  There are availability of various facilities l...
# 3236  Cctv surveillance are provided here. There is ...
# 3452  Ground and first floor, Ground floor: Ground f...
#
#                                          furnishDetails  \
# 1110  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 1139                                                NaN
# 2563  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 3236  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 3452                                                NaN
#
#                                           features  \
# 1110                     ['Water Storage', 'Park']
# 1139                                           NaN
# 2563  ['Water Storage', 'Park', 'Visitor Parking']
# 3236                                           NaN
# 3452                                           NaN
#
#                                                  rating    area  \
# 1110  ['Environment4 out of 5', 'Safety4 out of 5', ...   884.0
# 1139  ['Environment4 out of 5', 'Safety4 out of 5', ...   594.0
# 2563  ['Environment4 out of 5', 'Lifestyle4 out of 5...   270.0
# 3236  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...   500.0
# 3452  ['Environment4 out of 5', 'Lifestyle4 out of 5...  1137.0
#
#           property_type
# 1110               flat
# 1139               flat
# 2563  independent-house
# 3236               flat
# 3452  independent-house
#
# [5 rows x 21 columns]

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3784, 21)

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(

)
# Out:
#                                   society  price    sector  price_per_sqft  \
# 1582  palam vihar extension west zone rwa    0.4  sector 2          4444.0
#
#                     areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 1582  Plot area 900(83.61 sq.m.)        6         4       2  not available
#
#       floorNum facing     agePossession  \
# 1582         2   West  5 to 10 Year Old
#
#                                         nearbyLocations furnishDetails  \
# 1582  ['Palam triangle', 'Palam Vihar Vyapar kendra'...            NaN
#
#                                                features   area  \
# 1582  ['Water purifier', 'Water Storage', 'Park', 'V...  900.0
#
#           property_type
# 1582  independent-house

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
