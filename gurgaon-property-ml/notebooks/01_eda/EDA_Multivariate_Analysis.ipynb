# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/gurgaon_properties_cleaned_v2.csv").drop_duplicates()
df.shape
# Out:
# (3659, 23)

# %%
df.head()
# Out:
#                  society  price      sector  price_per_sqft  \
# 0    ireo victory valley   2.99   sector 67         11832.0
# 1         not applicable   0.42    sector 4          5600.0
# 2            independent  17.00   sector 45         37777.0
# 3  signature global park   0.68  sohna road          8252.0
# 4   dlf new town heights   1.42   sector 90          4864.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2527(234.77 sq.m.)Built Up...        3         3
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                       Plot area 4500(418.06 sq.m.)        5         8
# 3                     Carpet area: 824 (76.55 sq.m.)        2         2
# 4             Super Built up area 2364(219.62 sq.m.)        4         4
#
#   balcony  floorNum      facing  ... super_built_up_area  built_up_area  \
# 0       3         4        East  ...              2527.0         2200.0
# 1       1         3         NaN  ...                 NaN            NaN
# 2      3+         3  North-East  ...                 NaN         4500.0
# 3       2         3         NaN  ...                 NaN            NaN
# 4      3+         8        East  ...              2364.0            NaN
#
#   carpet_area  study room  servant room  store room  pooja room  others  \
# 0      2100.0           0             1           0           0       0
# 1       750.0           0             0           0           0       0
# 2         NaN           1             1           1           1       0
# 3       824.0           0             0           0           0       0
# 4         NaN           0             1           1           0       0
#
#    furnishing_type  luxury_score
# 0                2            37
# 1                2            26
# 2                1           152
# 3                0           113
# 4                0            31
#
# [5 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# property type VS Price

# %%
sns.boxplot(x=df['property_type'],y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# Property Type vs Area

# %%
sns.barplot(x=df['property_type'],y=df['built_up_area'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
df = df[df['built_up_area'] != 737147]
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
plt.show()

# %%
# outliers...
df[df['price_per_sqft']>100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#           property_type                      society     sector  price  \
# 49    independent-house                  independent  sector 38   8.00
# 61                 flat           ambience caitriona  sector 24  14.00
# 95    independent-house                  independent  sector 12   6.00
# 249   independent-house         eros rosewood villas  sector 49   2.75
# 260   independent-house         bhim nagar, sector 6   sector 6   0.85
# 1012  independent-house                  independent  sector 28   4.50
# 1065  independent-house                dlf the grove  sector 54   5.70
# 1130  independent-house                  independent  sector 17   3.50
# 1212  independent-house           vipul tatvam villa  sector 48   7.25
# 1575  independent-house          huda plot sector 38  sector 38   4.30
# 2204  independent-house  unitech nirvana birch court  sector 50   7.10
# 2323  independent-house            vatika india next  sector 82   7.00
# 2357  independent-house                  independent   sector 4   0.60
# 2367  independent-house                  independent  sector 23   2.80
# 2445  independent-house       unitech deerwood chase  sector 50   8.45
# 2488  independent-house                  independent  sector 54   3.75
# 2519  independent-house                    rk excelo  sector 12   0.60
# 2652  independent-house                        ansal  sector 43   1.85
# 2707  independent-house       emaar the palm springs  sector 54  24.00
# 2716  independent-house       dlf city plots phase 2  sector 25  10.50
# 2874  independent-house                  independent  sector 55   1.45
# 2981  independent-house     unitech uniworld resorts  sector 33  10.00
# 2988  independent-house                  independent  sector 57   8.00
# 3056  independent-house                   ardee city  sector 52   5.50
# 3276  independent-house                  independent  sector 12   3.50
# 3507  independent-house     unitech uniworld resorts  sector 33   9.50
# 3583  independent-house                  independent  sector 24  10.00
# 3601  independent-house       dlf city plots phase 2  sector 25  10.00
#
#       price_per_sqft   area  \
# 49          230547.0  347.0
# 61          200000.0  700.0
# 95          315789.0  190.0
# 249         178571.0  154.0
# 260         126865.0   67.0
# 1012        125000.0  360.0
# 1065        211111.0  270.0
# 1130        218750.0  160.0
# 1212        201388.0  360.0
# 1575        245398.0  175.0
# 2204        283333.0  251.0
# 2323        194444.0  360.0
# 2357        105263.0   57.0
# 2367        161849.0  173.0
# 2445        235376.0  359.0
# 2488        234375.0  160.0
# 2519        120000.0   50.0
# 2652        308333.0   60.0
# 2707        600000.0  400.0
# 2716        261194.0  402.0
# 2874        241666.0   60.0
# 2981        181818.0  550.0
# 2988        266666.0  300.0
# 3056        183333.0  300.0
# 3276        133079.0  263.0
# 3507        173992.0  546.0
# 3583        229885.0  435.0
# 3601        400000.0  250.0
#
#                                            areaWithType  super_built_up_area  \
# 49    Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 61                     Built Up area: 700 (65.03 sq.m.)                  NaN
# 95    Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 249   Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 260                            Plot area 67(6.22 sq.m.)                  NaN
# 1012                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 1065                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 1130                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1212                         Plot area 360(33.45 sq.m.)                  NaN
# 1575  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 2204                          Plot area 240(22.3 sq.m.)                  NaN
# 2323  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2357                            Plot area 57(5.3 sq.m.)                  NaN
# 2367  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 2445                         Plot area 359(33.35 sq.m.)                  NaN
# 2488                         Plot area 160(14.86 sq.m.)                  NaN
# 2519  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 2652                           Plot area 60(5.57 sq.m.)                  NaN
# 2707                         Plot area 400(37.16 sq.m.)                  NaN
# 2716                         Plot area 402(37.35 sq.m.)                  NaN
# 2874                           Plot area 60(5.57 sq.m.)                  NaN
# 2981                          Plot area 550(51.1 sq.m.)                  NaN
# 2988                         Plot area 300(27.87 sq.m.)                  NaN
# 3056                         Plot area 300(27.87 sq.m.)                  NaN
# 3276  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 3507                         Plot area 546(50.73 sq.m.)                  NaN
# 3583                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 3601                         Plot area 250(23.23 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 49            347.0        215.0
# 61            700.0          NaN
# 95              NaN       1600.0
# 249             NaN       1650.0
# 260            67.0          NaN
# 1012          360.0          NaN
# 1065          270.0          NaN
# 1130          160.0          NaN
# 1212          360.0          NaN
# 1575          145.0          NaN
# 2204          240.0          NaN
# 2323         3900.0       3743.0
# 2357           57.0          NaN
# 2367          160.0        150.0
# 2445          359.0          NaN
# 2488          160.0          NaN
# 2519           30.0         15.0
# 2652           60.0          NaN
# 2707          400.0          NaN
# 2716          402.0          NaN
# 2874           60.0          NaN
# 2981          550.0          NaN
# 2988          300.0          NaN
# 3056          300.0          NaN
# 3276         4800.0       4400.0
# 3507          546.0          NaN
# 3583            NaN        435.0
# 3601          250.0          NaN

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# chech outliers...
df[df['bedRoom'] >= 10].shape
# Out:
# (70, 23)

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
df[(df['property_type']=='independent-house') & (df['floorNum']>10)]
# Out:
#                       society  price      sector  price_per_sqft  \
# 117   indiabulls centrum park   3.25  sector 103          8125.0
# 264          suncity township   2.00   sector 54         30968.0
# 895               independent   1.80   sector 92          7627.0
# 1106              greenopolis   0.70   sector 89          5397.0
# 1453               ninex city   1.75   sector 76          6250.0
# 1616              spaze privy   3.10   sector 72          8486.0
# 1739          godrej meridien   5.60  sector 106         14000.0
# 1785        suncity avenue 76   0.75   sector 76         10067.0
# 1879           dlf the arbour   8.50   sector 63         21519.0
# 1901              spaze privy   3.09   sector 72          6981.0
# 1954   vatika the seven lamps   1.60   sector 82          6597.0
# 2431      ireo victory valley   8.00   sector 67         22222.0
# 2780      satya the hermitage   3.15  sector 103          6702.0
# 3372           ats tourmaline   1.87  sector 109          8697.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 117                        Plot area 4000(371.61 sq.m.)        4         3
# 264   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 895                  Built Up area: 2360 (219.25 sq.m.)        4         5
# 1106                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1453                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 1616                       Plot area 3653(339.37 sq.m.)        5         5
# 1739                       Plot area 4000(371.61 sq.m.)        5         4
# 1785  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 1879                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 1901  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 1954                       Plot area 2425(225.29 sq.m.)        4         4
# 2431                        Plot area 400(334.45 sq.m.)        6         7
# 2780                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 3372                 Built Up area: 2150 (199.74 sq.m.)        3         4
#
#      balcony  floorNum      facing  ... super_built_up_area  built_up_area  \
# 117       3+        20         NaN  ...                 NaN         4000.0
# 264        3        11       North  ...                 NaN           60.0
# 895        0        13         NaN  ...                 NaN         2360.0
# 1106       2        14  North-East  ...                 NaN         1297.0
# 1453       0        14         NaN  ...                 NaN            NaN
# 1616      3+        21         NaN  ...                 NaN         3653.0
# 1739      3+        33  North-East  ...                 NaN         4000.0
# 1785       2        11  North-East  ...                 NaN          745.0
# 1879      3+        27         NaN  ...                 NaN         3950.0
# 1901      3+        14        East  ...                 NaN         3653.0
# 1954      3+        16       North  ...                 NaN         2425.0
# 2431      3+        51  North-East  ...                 NaN         3600.0
# 2780       0        12        East  ...                 NaN         4700.0
# 3372       0        12         NaN  ...                 NaN         2150.0
#
#      carpet_area  study room  servant room  store room  pooja room  others  \
# 117          NaN           0             0           0           0       0
# 264         59.0           0             1           0           0       0
# 895          NaN           0             0           0           0       0
# 1106         NaN           0             0           0           0       0
# 1453      2800.0           0             0           0           0       0
# 1616         NaN           0             0           0           0       0
# 1739         NaN           1             1           1           1       0
# 1785         NaN           0             0           0           0       0
# 1879         NaN           0             0           0           0       0
# 1901      2922.0           0             1           0           0       0
# 1954         NaN           0             1           0           0       0
# 2431         NaN           1             1           0           1       0
# 2780         NaN           0             0           0           0       0
# 3372         NaN           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 117                 0            51
# 264                 1             7
# 895                 0             0
# 1106                0             0
# 1453                0             0
# 1616                0             0
# 1739                0           151
# 1785                0            40
# 1879                0            61
# 1901                2            33
# 1954                0            94
# 2431                2            49
# 2780                0            61
# 3372                0             0
#
# [14 rows x 23 columns]

# %%
sns.heatmap(pd.crosstab(index=df['property_type'],
                        columns=df['agePossession'],
                        values=df['price'],
                        aggfunc='mean'), annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.crosstab(index=df['property_type'],
                        columns=df['bedRoom'],
                        values=df['price'],
                        aggfunc='mean'), annot=True)


plt.show()

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.crosstab(df['property_type'],df['sector']).sort_index(axis=1))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
import re
avg_price_per_sector=df.groupby('sector')['price'].mean().reset_index()

def extract_sector_number(sector_name):
  match = re.search(r'\d+', sector_name)
  if match:
    return int(match.group())
  else:
    return float("inf")


avg_price_per_sector['sector_number']=avg_price_per_sector['sector'].apply(extract_sector_number)
avg_price_per_sector=avg_price_per_sector.sort_values(by='sector_number')

plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
sns.scatterplot(x=df[df['area']<10000]['area'],y=df[df['area']<10000]['price'],hue=df[df['area']<10000]['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.scatterplot(x=df[df['area']<10000]['area'],y=df[df['area']<10000]['price'],hue=df[df['area']<10000]['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.scatterplot(x=df[df['area']<10000]['area'],y=df[df['area']<10000]['price'],hue=df[df['area']<10000]['furnishing_type'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
